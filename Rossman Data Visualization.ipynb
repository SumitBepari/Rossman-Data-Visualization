# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
Sales_data = pd.read_csv('train.csv', parse_dates=True, index_col='Date')
# Out:
# C:\Sumit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Sales_data.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday
# Date
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1

# %%
SD2013 = Sales_data.loc['2013']

# %%
SD2013.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-12-31      1          2   2362        298     1      0            0
# 2013-12-31      2          2   2148        268     1      0            0
# 2013-12-31      3          2   4081        463     1      0            0
# 2013-12-31      4          2   9813       1323     1      0            0
# 2013-12-31      5          2   2009        241     1      0            0
#
#             SchoolHoliday
# Date
# 2013-12-31              1
# 2013-12-31              1
# 2013-12-31              1
# 2013-12-31              1
# 2013-12-31              1

# %%
sns.lmplot(x='Store', y='Sales', data=SD2013, col='Promo', x_jitter=0.05)

# %%
#inference:When there is promotion, the price is higher

# %%
SD2014 = Sales_data.loc['2014']

# %%
sns.lmplot(x='Store', y='Sales', data=SD2014, col='Promo', x_jitter=0.05)

# %%
#inference:When there is promotion, the price is higher

# %%
SD2015 = Sales_data.loc['2015']

# %%
sns.lmplot(x='Store', y='Sales', data=SD2015, col='Promo', x_jitter=0.05)

# %%
#inference:When there is promotion, the price is higher

# %%
sns.lmplot(x='Store', y='Sales', data=Sales_data, col='SchoolHoliday')

# %%
sns.lmplot(x='Store', y='Sales', data=Sales_data, col='DayOfWeek')

# %%
sns.scatterplot(x='Customers', y='Sales', data=Sales_data)

# %%
#Inference : More Customers, more Sales

# %%
sns.lmplot(x='Customers', y='Sales', data=Sales_data, hue='DayOfWeek')

# %%
#Inference : Seems to have some garbage data. Customers count cannot be negative.
